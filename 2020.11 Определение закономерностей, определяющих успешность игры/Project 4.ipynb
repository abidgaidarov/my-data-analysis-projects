# %% [markdown]
# Привет, Абид! Меня зовут Максим Слотин, я буду делать ревью твоего итогового проекта первого модуля. Давай будем общаться на «ты».
#
# Ты проделал большую исследовательскую работу! Твой проект очень хорошо структурирован, ты делаешь хорошие понятные выводы и выбираешь наглядные типы графиков. Мои комментарии будут в ячейках "Комментарий от ревьюера".
#
# <div class="alert alert-danger">
# <h2> Комментарии от ревьюера №1</h2>
# Красным цветом обозначены комментарии, на которые тебе нужно обратить внимание в первую очередь, чтобы я принял проект.
# </div>
# <div class="alert alert-warning">
# <h2> Комментарии от ревьюера №1</h2>
# Желтым цветом отмечено то, что ты можешь сделать немного по другому. Ты можешь учесть эти комментарии при выполнении следующих проектов.
# </div>
# <div class="alert alert-success">
# <h2> Комментарии от ревьюера №1</h2>
# Зелёным цветом обозначены твои удачные решения, которые ты без сомнения можешь применять в будущих проектах.
# </div>
#
# #### Пожалуста, не удаляй мои комментарии и относись к ним бережно. При повторной проверке, я буду ориентироваться на них.
#
# ###### Можешь под моими комментариями оставлять свои, в которых опиши свои испарвления. Это облегчит процесс проверки и мне, и тебе  :)
#
# Например, вот так:
#
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
# </div>
# ---

# %% [markdown]
# </div>
# <div class="alert alert-success">
# <h2> Комментарии от ревьюера №2</h2>
#
# У тебя в итоге вышел отличный проект)
#
# Спасибо, что довольно внимательно и терпеливо отреагировал на мои комментарии 😊
#
# Желаю тебе дальше успехов в учебе)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Привет, Максим!
# </div>

# %% [markdown]
# # Определение закономерностей, определяющих успешность игры

# %% [markdown]
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и мы планируем кампанию на 2017-й. Нужно отработать принцип работы с данными.

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 1. Откроем файл с данными и изучим общую информацию

# %% [markdown]
# Имортируем необходимые библиотеки:

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарии от ревьюера №1</h2>
#
# Обрати внимание, что нужно обязательно прогонять целиком весь код перед отправкой через кнопку вверху restart kernel
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# Откроем файлы с данными:

# %%
df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# Выведем основную информацию:

# %%
display(df.info())
display(df.head())
display(df.describe())
display(df.duplicated().value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# ...

# %% [markdown]
# Изучили общую информацию.
# Файл содержит следующие столбцы:
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Имеются пропущенные значения. Дубликаты отсутствуют.

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 2. Подготовим данные

# %% [markdown]
# ### 2.1. Заменим названия столбцов (приведем к нижнему регистру)

# %%
df.columns = [x.lower() for x in df.columns]
df.head(1)
# Out:
#          name platform  year_of_release   genre  na_sales  eu_sales  jp_sales  \
# 0  Wii Sports      Wii           2006.0  Sports     41.36     28.96      3.77
#
#    other_sales  critic_score user_score rating
# 0         8.45          76.0          8      E

# %% [markdown]
# ### 2.2. Обработаем пропуски

# %%
df1 = df.copy()
df1.dropna(subset=['year_of_release'], inplace=True)
df1.dropna(subset=['name'], inplace=True)

# %% [markdown]
# Проверим какую часть данных потеряли в результате удаления строк:

# %%
len(df1)/len(df)
# Out:
# 0.9837870176488184

# %% [markdown]
# Потеряли менее 1%, что является отличным результатом. Пропуски в столбцах `critic_score`, `user_score` и `rating` пока не трогаем.

# %% [markdown]
# ### 2.3. Преобразуйте данные в нужные типы

# %%
df1['year_of_release'] = df1['year_of_release'].astype('int64')

# %%
df1['user_score'] = pd.to_numeric(df1['user_score'], errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             9768 non-null object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 2.4. Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец

# %%
df1['total_sales'] = df1['na_sales'] + df1['eu_sales'] + df1['jp_sales'] + df1['other_sales']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарии от ревьюера №1</h2>
#
# Тут все супер 👌
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 3. Проведем исследовательский анализ данных

# %% [markdown]
# ### 3.1. Посмотрим, сколько игр выпускалось в разные годы

# %%
year_pivot = df1.pivot_table(index='year_of_release', values='name', aggfunc='nunique')

# %%
year_pivot['name'].plot(label='Количество', grid=True)
plt.title('Количество выпущенных игр по годам')
plt.xlabel('Год')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарии от ревьюера №1</h2>
#
# Зачем линия с годом на графике отдельно внизу? 🤔
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Убрал.
# </div>

# %% [markdown]
# Пик пришел на 2008-2009 годы, после чего вероятно игры на телефонах начали сильно теснить остальные платформы.

# %% [markdown]
# ### 3.2. Посмотрим, как менялись продажи по платформам

# %% [markdown]
# Определим топ15 самых популярных платформ.

# %%
platform_pivot = df1.pivot_table(index='platform', values='name', aggfunc='count')
top8_platforms = platform_pivot.sort_values(by='name', ascending=False).head(15).reset_index()
top8_platforms
# Out:
#    platform  name
# 0       PS2  2127
# 1        DS  2121
# 2       PS3  1306
# 3       Wii  1286
# 4      X360  1232
# 5       PSP  1193
# 6        PS  1190
# 7        PC   957
# 8       GBA   811
# 9        XB   803
# 10       GC   542
# 11      3DS   512
# 12      PSV   429
# 13      PS4   392
# 14      N64   316

# %% [markdown]
# Постороим графики изменения количества выпущенных игр на топ15 платформ.

# %%
for top_platform in top8_platforms['platform']:
    df1.query("platform == @top_platform").pivot_table(index='year_of_release', values='name', aggfunc='count').plot(kind='bar', grid=True, label=top_platform)
    plt.title('Количество выпущенных игр по годам на ' + top_platform)
    plt.xlabel('Год')
    plt.ylabel('Количество')
    plt.legend(loc='upper left')

# %% [markdown]
# ### 3.3. Возьмем данные за соответствующий актуальный период

# %% [markdown]
# Обратили внимание, что срок за который исчезают старые и появляются новые платформы это условно 10 лет. Значит в дальнейшем анализе будем использовать данные за этот период. Определим платформы, которые появились после 2006 года.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарии от ревьюера №1</h2>
#
# Попробуй еще точно оценить значение среднего  срока жизни платформы не через визуальную оценку количества лет, а математически)
#
# </div>

# %% [markdown]
# Определим медианное время жизни платформы при заданном минимальном уровне продаж

# %%
threshold = 10 #миллионов
report = df1.groupby(['platform', 'year_of_release']).agg({'total_sales':'sum'}).reset_index()
report = report.query("total_sales > @threshold")
report = report.groupby(['platform']).agg({'year_of_release':'nunique'}).rename(columns = {'year_of_release':'lifetime'})
median_platform_lifetime = int(report.median()[0])
print('Медианное время жизни платформы при уровне продаж {} млн. составляет {} лет.'.format(threshold, median_platform_lifetime))
# Out:
# Медианное время жизни платформы при уровне продаж 10 млн. составляет 6 лет.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Готово.
# </div>

# %%
new_platforms = df1.pivot_table(index='platform', values='year_of_release', aggfunc='min').sort_values(by='year_of_release', ascending=False).query("year_of_release>=2006").reset_index()
new_platforms
# Out:
#   platform  year_of_release
# 0     XOne             2013
# 1      PS4             2013
# 2     WiiU             2012
# 3      3DS             2011
# 4      PSV             2011
# 5      PS3             2006
# 6      Wii             2006

# %% [markdown]
# Создадим новую таблицу с платформами новее 2006 года; а также PC, которая не устаревает.

# %%
df2 = df1.copy()
new_platforms_list = new_platforms['platform']
df2 = df2[(df2['platform'].isin(new_platforms_list)) | (df2['platform']=='PC')]

# %% [markdown]
# ### 3.4. Определим какие платформы лидируют по продажам, растут или падают

# %%
for new_platform in df2['platform'].unique():
    df2.query("platform == @new_platform").pivot_table(index='year_of_release', values='total_sales', aggfunc='sum').plot(kind='bar', grid=True, label=top_platform)
    plt.title('Суммарные продажи игр по годам на ' + new_platform)
    plt.xlabel('Год')
    plt.ylabel('Млн копий')
    plt.legend(loc='upper left')

# %% [markdown]
# XBox One и PS4 являются наиболее потенциально прибыльными на ближайщий период. WiiU хоть и выпущена относительно недавно, но данный форм-фактор стремительно теряет интерес пользователей, так как эта целевая аудитория переходит на игры на смартфонах.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарии от ревьюера №1</h2>
#
# Все таки не совсем наглядно, какая платформа лидирует по количеству продаж, тяжело на основе твоих графиков по каждой платформе сравнить платформы друг с другом
#
# Я тебе предлагаю построить или какую-нибудь общую гистограмму по годам или за весь период
#
# </div>

# %%
sales_plot = df2.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(xlim=(2006, 2016))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Готово.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарии от ревьюера №1</h2>
#
# При все при этом, мне нравится твоя автоматизация рисования графиков, здорово, что ты это умеешь)
#
# </div>

# %% [markdown]
# ### 3.5. Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
sns.boxplot(x='platform', y='total_sales', data=df2)
plt.ylim(0, 3)
# Out:
# (0, 3)

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарии от ревьюера №1</h2>
#
# Давай немного уменьшим представленность хвостов на графике и больше акцентируем внимание на "ящиках", чтобы можно было оценить кличественно дисперсию
#
# Хвосты я предлагаю тебе рассмотреть отдельно и посмотреть чем они представлены
#
# </div>

# %% [markdown]
# Избавимся от длинных хвостов:

# %%
for platform in df2['platform'].unique():
    p95 = df2.query('platform == @platform')['total_sales'].quantile(0.95) # это верхняя граница выбросов продаж по текущей платформе
    df2_p95 = df2.query('platform == @platform and total_sales > @p95') # это выборка по одной текущий платформе
    sns.boxplot(x='platform', y='total_sales', data = df2_p95)
    plt.show()

# %% [markdown]
# Посмотрим, чем представлены выбросы по общим продажам отдельно по каждой платформе.

# %%
for platform in df2['platform'].unique():
    p95 = df2.query('platform == @platform')['total_sales'].quantile(0.95) # это верхняя граница выбросов продаж по текущей платформе
    display('Игры, попавшие в выбросы по общим продажам для ' + platform)
    display(df2.query('platform == @platform and total_sales > @p95')['name'].unique()) # это игры-выбросы
# Out:
# 'Игры, попавшие в выбросы по общим продажам для Wii'
# array(['Wii Sports', 'Mario Kart Wii', 'Wii Sports Resort', 'Wii Play',
#        'New Super Mario Bros. Wii', 'Wii Fit', 'Wii Fit Plus',
#        'Super Smash Bros. Brawl', 'Super Mario Galaxy', 'Just Dance 3',
#        'Just Dance 2', 'Wii Party', 'Mario Party 8',
#        'Mario & Sonic at the Olympic Games', 'Super Mario Galaxy 2',
#        'Just Dance', 'The Legend of Zelda: Twilight Princess',
#        'Just Dance 4', 'Zumba Fitness', 'Donkey Kong Country Returns',
#        'LEGO Star Wars: The Complete Saga', "Link's Crossbow Training",
#        'Animal Crossing: City Folk', 'Guitar Hero III: Legends of Rock',
#        'Mario & Sonic at the Olympic Winter Games',
#        'Michael Jackson: The Experience', 'Carnival Games',
#        'The Legend of Zelda: Skyward Sword', 'EA Sports Active',
#        'Big Brain Academy: Wii Degree',
#        'Mario & Sonic at the London 2012 Olympic Games',
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Готово.
# </div>

# %% [markdown]
# ### 3.6. Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков

# %% [markdown]
# Рассмотрим самую популярную платформу последних 10 лет - PS3.

# %%
ps3 = df2.query("platform == 'PS3'")

# %%
pd.plotting.scatter_matrix(ps3[['total_sales', 'critic_score', 'user_score']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f60b5ac12d0>,
# ...
#       dtype=object)

# %% [markdown]
# Корреляция отзывов пользователей и продаж:

# %%
ps3['total_sales'].corr(ps3['user_score'])
# Out:
# 0.12841562938563028

# %% [markdown]
# Корреляция отзывов критиков и продаж:

# %%
ps3['total_sales'].corr(ps3['critic_score'])
# Out:
# 0.4327589578997135

# %% [markdown]
# Определили, что отзывы пользователей и критиков не вляют на продажи. Корреляция низкая.

# %% [markdown]
# ### 3.7. Посмотрим на общее распределение игр по жанрам

# %%
genre_distribution = df2.pivot_table(index='genre', values='name', aggfunc='nunique').sort_values(by='name', ascending=False)
display(genre_distribution)
genre_distribution['name'].plot(kind='pie', grid=True)
# Out:
#               genre  name
# genre
# Action            1   887
# Sports            1   457
# Misc              1   445
# Role-Playing      1   379
# Adventure         1   316
# Shooter           1   309
# Simulation        1   252
# Strategy          1   246
# Racing            1   207
# Fighting          1   134
# Platform          1   125
# Puzzle            1   104

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарии от ревьюера №1</h2>
#
# Было бы здорово по больше выводов и особенно выводов, которые синтезируются из разных секций одновременно 😉
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 4. Составим портрет пользователя каждого региона

# %% [markdown]
# ### 4.1. Определим для пользователя каждого региона самые популярные платформы (топ-5)

# %% [markdown]
# Топ-5 платформ для пользователя из Северной Америки:

# %%
na_top5_platforms = df2.pivot_table(index='platform', values='na_sales', aggfunc='sum').sort_values(by='na_sales', ascending=False).head(5)
na_top5_platforms.plot(kind='bar', ylim=(0,500), grid=True)

# %% [markdown]
# Топ-5 платформ для пользователя из Европы:

# %%
eu_top5_platforms = df2.pivot_table(index='platform', values='eu_sales', aggfunc='sum').sort_values(by='eu_sales', ascending=False).head(5)
eu_top5_platforms.plot(kind='bar', ylim=(0,500), grid=True)

# %% [markdown]
# Топ-5 платформ для пользователя из Японии:

# %%
jp_top5_platforms = df2.pivot_table(index='platform', values='jp_sales', aggfunc='sum').sort_values(by='jp_sales', ascending=False).head(5)
jp_top5_platforms.plot(kind='bar', ylim=(0,500), grid=True)

# %% [markdown]
# Топ-5 платформ для пользователя из остального мира:

# %%
other_top5_platforms = df2.pivot_table(index='platform', values='other_sales', aggfunc='sum').sort_values(by='other_sales', ascending=False).head(5)
other_top5_platforms.plot(kind='bar', ylim=(0,500), grid=True)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарии от ревьюера №1</h2>
#
# Если бы ты автоматизировал заполнение и этой секции графиков, то был просто высший пилотаж
#
# </div>

# %% [markdown]
# В итоге получили следующие рейтинги:
# - Северная Америка: Wii, PS3, PS4, PC, XOne;
# - Европа: PS3, Wii, PS4, PC, 3DS;
# - Япония: 3DS, PS3, Wii, PSV, PS4;
# - остальной мир: PS3, Wii, PS4, PC, XOne.

# %% [markdown]
# ### 4.2. Определим для пользователя каждого региона самые  популярные жанры (топ-5)

# %% [markdown]
# Топ-5 жанров для пользователя из Северной Америки:

# %%
na_top5_genres = df2.pivot_table(index='genre', values='na_sales', aggfunc='sum').sort_values(by='na_sales', ascending=False).head(5)
na_top5_genres.plot(kind='bar', ylim=(0,300), grid=True)

# %% [markdown]
# Топ-5 жанров для пользователя из Европы:

# %%
eu_top5_genres = df2.pivot_table(index='genre', values='eu_sales', aggfunc='sum').sort_values(by='eu_sales', ascending=False).head(5)
eu_top5_genres.plot(kind='bar', ylim=(0,300), grid=True)

# %% [markdown]
# Топ-5 жанров для пользователя из Японии:

# %%
jp_top5_genres = df2.pivot_table(index='genre', values='jp_sales', aggfunc='sum').sort_values(by='jp_sales', ascending=False).head(5)
jp_top5_genres.plot(kind='bar', ylim=(0,300), grid=True)

# %% [markdown]
# Топ-5 жанров для пользователя из остального мира:

# %%
other_top5_genres = df2.pivot_table(index='genre', values='other_sales', aggfunc='sum').sort_values(by='other_sales', ascending=False).head(5)
other_top5_genres.plot(kind='bar', ylim=(0,300), grid=True)

# %% [markdown]
# В итоге получили следующие рейтинги:
# - Северная Америка: Action, Sports, Shooter, Misc, Role-playing;
# - Европа: Action, Sports, Shooter, Misc, Role-playing;
# - Япония: Role-Playing, Action, Sports, Misc, Platform;
# - остальной мир: Action, Sports, Shooter, Misc, Role-playing.

# %% [markdown]
# ### 4.3. Определим для пользователя каждого региона влияет ли на покупки рейтинг ESRB

# %% [markdown]
# Определим какие есть значения в колонке с рейтингом ESRB:

# %%
df2['rating'].unique()
# Out:
# array(['E', 'M', nan, 'T', 'E10+', 'K-A', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Здесь:
# - E - "Everyone" - для всех возрастов;
# - K-A - "Kids to Adults" - для всех возрастов;
# - EC - "Early childhood" - для всех возрастов;
# - E10+ - "Everyone 10+" - для возрастов 10+;
# - T - "Teen" - для возрастов 13+;
# - M - "Mature" - для возрастов 18+;
# - RP - "Rating pending" - рейтинг еще не присвоен.
#
# С целью определения влияния рейтинга ESRB на покупки, заменим буквенные значения на условный порядковый номер:
# - E, K-A, EC - 0;
# - EC-10+ - 1;
# - T - 2;
# - M - 3.
# - RP - отбросим, так как рейтинг не известен.

# %%
df3 = df2.copy()
df3 = df3[df3.rating!='RP'].dropna(subset=['rating'])

# %%
df3['rating_class'] = df3['rating'].replace(['E', 'M', 'T', 'E10+', 'K-A', 'EC'], [0, 3, 2, 1, 0, 1])

# %% [markdown]
# Определим корреляцию:

# %%
df3['na_sales'].corr(df3['rating_class'])
# Out:
# -0.02307378428130947

# %%
df3['eu_sales'].corr(df3['rating_class'])
# Out:
# 0.01504248861800591

# %%
df3['jp_sales'].corr(df3['rating_class'])
# Out:
# -0.03453226107908848

# %%
df3['other_sales'].corr(df3['rating_class'])
# Out:
# 0.03660472200344958

# %% [markdown]
# Определили, что зависимость во всех регионах отсутствует.

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 5. Проверим гипотезы

# %% [markdown]
# ### 5.1. Проверим гипотезу, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Выдвенем нулевую гипотезу, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, и альтернативную гипотезу, что и они различны.

# %%
df2 = df2.dropna(subset=['user_score'])

# %%
alpha = 0.05

xone_rating = df2.query("platform == 'XOne'").pivot_table(index='name', values='user_score', aggfunc='mean')['user_score'].values
pc_rating = df2.query("platform == 'PC'").pivot_table(index='name', values='user_score', aggfunc='mean')['user_score'].values

results = st.ttest_ind(
    xone_rating, 
    pc_rating, 
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.9031388940226644e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# Определили, что средние пользовательские рейтинги платформ Xbox One и PC различны.

# %% [markdown]
# ### 5.2. Проверим гипотезу, что средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# Выдвенем нулевую гипотезу, что средние пользовательские рейтинги жанров Action и Sports одинаковые, и альтернативную гипотезу, что и они отличаются.

# %%
alpha = 0.05

action_rating = df2.query("genre == 'Action'").pivot_table(index='name', values='user_score', aggfunc='mean')['user_score'].values
sports_rating = df2.query("genre == 'Sports'").pivot_table(index='name', values='user_score', aggfunc='mean')['user_score'].values

results = st.ttest_ind(
    action_rating, 
    sports_rating, 
    equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 7.056277841557343e-07
# Отвергаем нулевую гипотезу

# %% [markdown]
# Определили, что средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# <div class="alert alert-info">
#
# ## Шаг 6. Общий вывод

# %% [markdown]
# В результате проделанной работы определили закономерности, определяющие успешность игры.
# В планируемой рекламной компании стоит сделать ставку на игры выпущенные на XBox One и PS4, так эти консоли выпущенны недавно, и у них максимальный потенциал для роста. Самые популярные жанры среди пользователей:  Action, Sports и Shooter.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарии от ревьюера №1</h2>
#
# В целом у тебя очень хороший проект, предлагаю довести нам его с тобой до совершенства, обрати внимание на мои комментарии по следующим моментам:
#
#     1) Нужно сделать по репрезентативнее некторые графики;
#     2) Добавь немного "анализа" и "выводов" в ряде мест, где я это отмечаю;
#
# Жду скорее твою работу!)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ ОТ УЧЕНИКА:</b>
#
# Знаю, сильно задержался... Нахожусь на рабочей вахте в Саудовской Аравии, нет возможности сейчас заниматься, к огромному сожалению... Надеюсь, что все самое необходимое исправил. Спасибо!
# </div>
